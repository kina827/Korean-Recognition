# %%
# run command 'conda install scikit-image' on project's v-env
# run command 'conda install pandas' on project's v-env

# %%
DEBUG_TRAIN = False
DEBUG_DATA = False

# %%
def encode_from_utf8(x):
    return list(map(float,bin(int(x.encode().hex(),16))[2:]))

# %%
def decode_from_bin(x):
    res = ""
    for i in x:
        res+=str(round(i))
        pass
    return bytearray.fromhex(hex(int(res, 2))[2:]).decode()

# %%
def decode_from_bin2(x):
    res = ""
    for i in x:
        res+=str(int(i>0))
        pass
    return bytearray.fromhex(hex(int(res, 2))[2:]).decode()

# %%
import os
import torch
import numpy as np
import pandas as pd
from skimage import io, transform
from torch.utils.data import Dataset, DataLoader

class KoreanHandwritingDataset(Dataset):
    def __init__(self, csv_file, root_dir, transform=None):
        self.dataset = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        img_name = self.dataset.iloc[idx, 0]
        image = io.imread(img_name)
        label = self.dataset.iloc[idx, 1]
        label = np.array([label])
        sample = {'image': image, 'label': label}

        if self.transform:
            sample = self.transform(sample)

        return sample
    pass

# %%
class ToTensor(object):
    def __call__(self, sample):
        image, label = sample['image'], sample['label']
        # swap color axis because
        # numpy image: H x W x C
        # torch image: C X H X W
        image = image/255.0
        return {'image': torch.from_numpy(image.reshape(1,64,64)),
                'label': torch.tensor(encode_from_utf8(label[0]))}

# %%
from torchvision import transforms
csv_file = "./image-data-256/labels-map.csv"
root_dir = "./image-data-256/hangul-images"
batch_size=64
learning_rate=0.002
num_epoch=100

korean_dataset = KoreanHandwritingDataset(csv_file,root_dir, transform=transforms.Compose([ToTensor()]))
dataloader = DataLoader(korean_dataset, batch_size = batch_size, shuffle = True, num_workers = 0)
#dataloader = DataLoader(korean_dataset, batch_size = batch_size, shuffle = False, num_workers = 0)

# %%
import torch.nn as nn

class CNN(nn.Module):
    def __init__(self):
        super(CNN,self).__init__()
        self.avgpool1 = nn.AvgPool2d(2,2) # kernel size 2x2 (32 = 64/2)
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=16, kernel_size=5, stride=1, padding=1)
        self.relu1 = nn.ReLU()
        self.maxpool1 = nn.MaxPool2d(2,2) # kernel size 2x2 (32 = 64/2)
        self.conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=5, stride=1, padding=1)
        self.relu2 = nn.ReLU()
        self.maxpool2 = nn.MaxPool2d(2,2) # kernel size 2x2 (16 = 32/2)
        self.linear1 = nn.Linear(1152,378)
        self.relu3 = nn.ReLU()
        self.linear2 = nn.Linear(378,128)
        self.relu4 = nn.ReLU()
        self.linear3 = nn.Linear(128,24)
        #self.sigmoid = nn.Sigmoid()
        pass
    def forward(self,x):
        out = self.avgpool1(x)
        if DEBUG_TRAIN : print('avgpool1: ', out.shape)
        out = self.conv1(out)
        if DEBUG_TRAIN : print('conv1: ', out.shape)
        out = self.relu1(out)
        if DEBUG_TRAIN : print('relu1: ', out.shape)
        out = self.maxpool1(out)
        if DEBUG_TRAIN : print('maxpool1: ', out.shape)
        out = self.conv2(out)
        if DEBUG_TRAIN : print('conv2: ', out.shape)
        out = self.relu2(out)
        if DEBUG_TRAIN : print('relu2: ', out.shape)
        out = self.maxpool2(out)
        if DEBUG_TRAIN : print('maxpool2: ', out.shape)
        out = out.view(out.size(0),-1)
        if DEBUG_TRAIN : print('view: ', out.shape)
        out = self.linear1(out)
        if DEBUG_TRAIN : print('linear1: ', out.shape)
        out = self.relu3(out)
        if DEBUG_TRAIN : print('relu3: ', out.shape)
        out = self.linear2(out)
        if DEBUG_TRAIN : print('linear2: ', out.shape)
        out = self.relu4(out)
        if DEBUG_TRAIN : print('relu4: ', out.shape)
        out = self.linear3(out)
        if DEBUG_TRAIN : print('linear3: ', out.shape)
        #out = self.sigmoid(out)
        #if DEBUG_TRAIN : print('sigmoid: ', out.shape)
        if DEBUG_TRAIN : print()
        return out

# %%
import torch.optim as optim
model=CNN().double()
loss_function=nn.BCEWithLogitsLoss()
#loss_function=nn.
optimizer= torch.optim.Adam(model.parameters(),lr=learning_rate)

# %% [markdown]
# > ## Training

# %%
import matplotlib.pyplot as plt

loss_arr=[]
for i in range(num_epoch):
    for j, sample in enumerate(dataloader):
        x = sample['image']
        y = sample['label']
        optimizer.zero_grad()
        output=model.forward(x)
        loss=loss_function(output,y)
        loss.backward()
        optimizer.step()
        if j == 0:
            if DEBUG_DATA:
                plt.figure(figsize=(32, 32))
                for k, img in enumerate(x):
                    plt.subplot(8, 8, k+1)
                    plt.imshow(img.squeeze())
                    plt.xticks([])
                    plt.yticks([])
                    pass
                plt.show()
            print('epoch: ', i+1, 'sequence: ', j, loss)
            loss_arr.append(loss.detach().numpy())
# Out:
# epoch:  1 sequence:  0 tensor(0.6903, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  2 sequence:  0 tensor(0.4179, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  3 sequence:  0 tensor(0.4016, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  4 sequence:  0 tensor(0.4046, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  5 sequence:  0 tensor(0.3924, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  6 sequence:  0 tensor(0.3903, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  7 sequence:  0 tensor(0.3810, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  8 sequence:  0 tensor(0.3588, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  9 sequence:  0 tensor(0.3391, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  10 sequence:  0 tensor(0.2964, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  11 sequence:  0 tensor(0.2829, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  12 sequence:  0 tensor(0.2615, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  13 sequence:  0 tensor(0.2555, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  14 sequence:  0 tensor(0.2405, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  15 sequence:  0 tensor(0.2342, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  16 sequence:  0 tensor(0.2203, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  17 sequence:  0 tensor(0.2241, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  18 sequence:  0 tensor(0.1964, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  19 sequence:  0 tensor(0.1839, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  20 sequence:  0 tensor(0.1782, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  21 sequence:  0 tensor(0.1635, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  22 sequence:  0 tensor(0.1659, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  23 sequence:  0 tensor(0.1507, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  24 sequence:  0 tensor(0.1378, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  25 sequence:  0 tensor(0.1441, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  26 sequence:  0 tensor(0.1272, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  27 sequence:  0 tensor(0.1045, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  28 sequence:  0 tensor(0.0842, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  29 sequence:  0 tensor(0.0843, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  30 sequence:  0 tensor(0.0892, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  31 sequence:  0 tensor(0.0720, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  32 sequence:  0 tensor(0.0571, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  33 sequence:  0 tensor(0.0514, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  34 sequence:  0 tensor(0.0476, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  35 sequence:  0 tensor(0.0412, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  36 sequence:  0 tensor(0.0367, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  37 sequence:  0 tensor(0.0271, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  38 sequence:  0 tensor(0.0195, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  39 sequence:  0 tensor(0.0147, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  40 sequence:  0 tensor(0.0161, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  41 sequence:  0 tensor(0.0148, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  42 sequence:  0 tensor(0.0108, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  43 sequence:  0 tensor(0.0080, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  44 sequence:  0 tensor(0.0050, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  45 sequence:  0 tensor(0.0032, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  46 sequence:  0 tensor(0.0047, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  47 sequence:  0 tensor(0.0058, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  48 sequence:  0 tensor(0.0026, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  49 sequence:  0 tensor(0.0024, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  50 sequence:  0 tensor(0.0031, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  51 sequence:  0 tensor(0.0016, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  52 sequence:  0 tensor(0.0016, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  53 sequence:  0 tensor(0.0013, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  54 sequence:  0 tensor(0.0010, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  55 sequence:  0 tensor(0.0009, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  56 sequence:  0 tensor(0.0009, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  57 sequence:  0 tensor(0.0009, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  58 sequence:  0 tensor(0.0008, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  59 sequence:  0 tensor(0.0008, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  60 sequence:  0 tensor(0.0007, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  61 sequence:  0 tensor(0.0007, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  62 sequence:  0 tensor(0.0005, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  63 sequence:  0 tensor(0.0005, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  64 sequence:  0 tensor(0.0006, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  65 sequence:  0 tensor(0.0005, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  66 sequence:  0 tensor(0.0005, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  67 sequence:  0 tensor(0.0004, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  68 sequence:  0 tensor(0.0004, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  69 sequence:  0 tensor(0.0005, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  70 sequence:  0 tensor(0.0004, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  71 sequence:  0 tensor(0.0004, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  72 sequence:  0 tensor(0.0003, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  73 sequence:  0 tensor(0.0004, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  74 sequence:  0 tensor(0.0004, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  75 sequence:  0 tensor(0.0003, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  76 sequence:  0 tensor(0.0003, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  77 sequence:  0 tensor(0.0003, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  78 sequence:  0 tensor(0.0002, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  79 sequence:  0 tensor(0.0002, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  80 sequence:  0 tensor(0.0003, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  81 sequence:  0 tensor(0.0002, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  82 sequence:  0 tensor(0.0003, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  83 sequence:  0 tensor(0.0003, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  84 sequence:  0 tensor(0.0002, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  85 sequence:  0 tensor(0.0002, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  86 sequence:  0 tensor(0.0003, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  87 sequence:  0 tensor(0.0002, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  88 sequence:  0 tensor(0.0002, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  89 sequence:  0 tensor(0.0002, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  90 sequence:  0 tensor(0.0002, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  91 sequence:  0 tensor(0.0001, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  92 sequence:  0 tensor(0.0002, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  93 sequence:  0 tensor(0.0002, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  94 sequence:  0 tensor(0.0001, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  95 sequence:  0 tensor(0.0002, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  96 sequence:  0 tensor(0.0002, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  97 sequence:  0 tensor(0.0002, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  98 sequence:  0 tensor(0.0002, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  99 sequence:  0 tensor(0.0001, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)
# epoch:  100 sequence:  0 tensor(0.0001, grad_fn=<BinaryCrossEntropyWithLogitsBackward>)

# %% [markdown]
# > ## Testing

# %%
with torch.no_grad():
    socreboard=[]
    for j, sample in enumerate(dataloader):
        x = sample['image']
        y = sample['label']
        
        output = model.forward(x)
        for i in range(len(output)):
            out = decode_from_bin2(output[i].tolist())
            y_ = decode_from_bin(y[i].tolist())
            print("출력 값: ", out,
                  ", 실제 값: ", y_)
            
            if out==y_:
                scoreboard.append(1)
            else:
                scoreboard.append(0)
            #print("실제 값: ", output[i].tolist(),
            #      ", 출력 값: ", y[i].tolist())
# Out:
# 출력 값:  전 , 실제 값:  전
# 출력 값:  월 , 실제 값:  월
# 출력 값:  밤 , 실제 값:  밤
# 출력 값:  파 , 실제 값:  파
# 출력 값:  앞 , 실제 값:  앞
# 출력 값:  은 , 실제 값:  은
# 출력 값:  군 , 실제 값:  군
# 출력 값:  꾸 , 실제 값:  꾸
# 출력 값:  가 , 실제 값:  가
# 출력 값:  올 , 실제 값:  올
# 출력 값:  간 , 실제 값:  간
# 출력 값:  향 , 실제 값:  향
# 출력 값:  력 , 실제 값:  력
# 출력 값:  제 , 실제 값:  제
# 출력 값:  재 , 실제 값:  재
# 출력 값:  고 , 실제 값:  고
# 출력 값:  방 , 실제 값:  방
# 출력 값:  석 , 실제 값:  석
# 출력 값:  외 , 실제 값:  외
# 출력 값:  루 , 실제 값:  루
# 출력 값:  오 , 실제 값:  오
# 출력 값:  운 , 실제 값:  운
# 출력 값:  변 , 실제 값:  변
# 출력 값:  복 , 실제 값:  복
# 출력 값:  프 , 실제 값:  프
# 출력 값:  파 , 실제 값:  파
# 출력 값:  년 , 실제 값:  년
# 출력 값:  접 , 실제 값:  접
# 출력 값:  물 , 실제 값:  물
# 출력 값:  예 , 실제 값:  예
# 출력 값:  발 , 실제 값:  발
# 출력 값:  물 , 실제 값:  물
# 출력 값:  세 , 실제 값:  세
# 출력 값:  인 , 실제 값:  인
# 출력 값:  군 , 실제 값:  군
# 출력 값:  히 , 실제 값:  히
# 출력 값:  신 , 실제 값:  신
# 출력 값:  꾸 , 실제 값:  꾸
# 출력 값:  과 , 실제 값:  과
# 출력 값:  야 , 실제 값:  야
# 출력 값:  속 , 실제 값:  속
# 출력 값:  중 , 실제 값:  중
# 출력 값:  소 , 실제 값:  소
# 출력 값:  여 , 실제 값:  여
# 출력 값:  손 , 실제 값:  손
# 출력 값:  순 , 실제 값:  순
# 출력 값:  잠 , 실제 값:  잠
# 출력 값:  부 , 실제 값:  부
# 출력 값:  구 , 실제 값:  구
# 출력 값:  점 , 실제 값:  점
# 출력 값:  번 , 실제 값:  번
# 출력 값:  군 , 실제 값:  군
# 출력 값:  근 , 실제 값:  근
# 출력 값:  정 , 실제 값:  정
# 출력 값:  공 , 실제 값:  공
# 출력 값:  선 , 실제 값:  선
# 출력 값:  한 , 실제 값:  한
# 출력 값:  서 , 실제 값:  서
# 출력 값:  저 , 실제 값:  저
# 출력 값:  합 , 실제 값:  합
# 출력 값:  제 , 실제 값:  제
# 출력 값:  마 , 실제 값:  마
# 출력 값:  격 , 실제 값:  격
# 출력 값:  보 , 실제 값:  보
# 출력 값:  스 , 실제 값:  스
# 출력 값:  망 , 실제 값:  망
# 출력 값:  품 , 실제 값:  품
# 출력 값:  가 , 실제 값:  가
# 출력 값:  설 , 실제 값:  설
# 출력 값:  집 , 실제 값:  집
# 출력 값:  먹 , 실제 값:  먹
# 출력 값:  접 , 실제 값:  접
# 출력 값:  음 , 실제 값:  음
# 출력 값:  통 , 실제 값:  통
# 출력 값:  불 , 실제 값:  불
# 출력 값:  쪽 , 실제 값:  쪽
# 출력 값:  치 , 실제 값:  치
# 출력 값:  럽 , 실제 값:  럽
# 출력 값:  러 , 실제 값:  러
# 출력 값:  만 , 실제 값:  만
# 출력 값:  판 , 실제 값:  판
# 출력 값:  리 , 실제 값:  리
# 출력 값:  지 , 실제 값:  지
# 출력 값:  감 , 실제 값:  감
# 출력 값:  동 , 실제 값:  동
# 출력 값:  반 , 실제 값:  반
# 출력 값:  산 , 실제 값:  산
# 출력 값:  우 , 실제 값:  우
# 출력 값:  환 , 실제 값:  환
# 출력 값:  코 , 실제 값:  코
# 출력 값:  연 , 실제 값:  연
# 출력 값:  추 , 실제 값:  추
# 출력 값:  창 , 실제 값:  창
# 출력 값:  오 , 실제 값:  오
# 출력 값:  라 , 실제 값:  라
# 출력 값:  워 , 실제 값:  워
# 출력 값:  해 , 실제 값:  해
# 출력 값:  보 , 실제 값:  보
# 출력 값:  손 , 실제 값:  손
# 출력 값:  치 , 실제 값:  치
# 출력 값:  양 , 실제 값:  양
# 출력 값:  육 , 실제 값:  육
# 출력 값:  산 , 실제 값:  산
# 출력 값:  먹 , 실제 값:  먹
# 출력 값:  시 , 실제 값:  시
# 출력 값:  통 , 실제 값:  통
# 출력 값:  생 , 실제 값:  생
# 출력 값:  습 , 실제 값:  습
# 출력 값:  피 , 실제 값:  피
# 출력 값:  씨 , 실제 값:  씨
# 출력 값:  송 , 실제 값:  송
# 출력 값:  잡 , 실제 값:  잡
# 출력 값:  활 , 실제 값:  활
# 출력 값:  확 , 실제 값:  확
# 출력 값:  료 , 실제 값:  료
# 출력 값:  금 , 실제 값:  금
# 출력 값:  거 , 실제 값:  거
# 출력 값:  갈 , 실제 값:  갈
# 출력 값:  부 , 실제 값:  부
# 출력 값:  적 , 실제 값:  적
# 출력 값:  망 , 실제 값:  망
# 출력 값:  움 , 실제 값:  움
# 출력 값:  집 , 실제 값:  집
# 출력 값:  재 , 실제 값:  재
# 출력 값:  르 , 실제 값:  르
# 출력 값:  말 , 실제 값:  말
# 출력 값:  너 , 실제 값:  너
# 출력 값:  키 , 실제 값:  키
# 출력 값:  반 , 실제 값:  반
# 출력 값:  책 , 실제 값:  책
# 출력 값:  작 , 실제 값:  작
# 출력 값:  중 , 실제 값:  중
# 출력 값:  간 , 실제 값:  간
# 출력 값:  공 , 실제 값:  공
# 출력 값:  능 , 실제 값:  능
# 출력 값:  려 , 실제 값:  려
# 출력 값:  트 , 실제 값:  트
# 출력 값:  각 , 실제 값:  각
# 출력 값:  배 , 실제 값:  배
# 출력 값:  터 , 실제 값:  터
# 출력 값:  각 , 실제 값:  각
# 출력 값:  정 , 실제 값:  정
# 출력 값:  학 , 실제 값:  학
# 출력 값:  두 , 실제 값:  두
# 출력 값:  히 , 실제 값:  히
# 출력 값:  자 , 실제 값:  자
# 출력 값:  락 , 실제 값:  락
# 출력 값:  법 , 실제 값:  법
# 출력 값:  화 , 실제 값:  화
# 출력 값:  평 , 실제 값:  평
# 출력 값:  년 , 실제 값:  년
# 출력 값:  쓰 , 실제 값:  쓰
# 출력 값:  년 , 실제 값:  년
# 출력 값:  무 , 실제 값:  무
# 출력 값:  월 , 실제 값:  월
# 출력 값:  특 , 실제 값:  특
# 출력 값:  민 , 실제 값:  민
# 출력 값:  년 , 실제 값:  년
# 출력 값:  업 , 실제 값:  업
# 출력 값:  녀 , 실제 값:  녀
# 출력 값:  순 , 실제 값:  순
# 출력 값:  미 , 실제 값:  미
# 출력 값:  임 , 실제 값:  임
# 출력 값:  술 , 실제 값:  술
# 출력 값:  름 , 실제 값:  름
# 출력 값:  마 , 실제 값:  마
# 출력 값:  토 , 실제 값:  토
# 출력 값:  점 , 실제 값:  점
# 출력 값:  향 , 실제 값:  향
# 출력 값:  확 , 실제 값:  확
# 출력 값:  생 , 실제 값:  생
# 출력 값:  르 , 실제 값:  르
# 출력 값:  점 , 실제 값:  점
# 출력 값:  니 , 실제 값:  니
# 출력 값:  나 , 실제 값:  나
# 출력 값:  질 , 실제 값:  질
# 출력 값:  럽 , 실제 값:  럽
# 출력 값:  타 , 실제 값:  타
# 출력 값:  식 , 실제 값:  식
# 출력 값:  평 , 실제 값:  평
# 출력 값:  안 , 실제 값:  안
# 출력 값:  문 , 실제 값:  문
# 출력 값:  디 , 실제 값:  디
# 출력 값:  통 , 실제 값:  통
# 출력 값:  극 , 실제 값:  극
# 출력 값:  드 , 실제 값:  드
# 출력 값:  품 , 실제 값:  품
# 출력 값:  불 , 실제 값:  불
# 출력 값:  학 , 실제 값:  학
# 출력 값:  려 , 실제 값:  려
# 출력 값:  그 , 실제 값:  그
# 출력 값:  녀 , 실제 값:  녀
# 출력 값:  깨 , 실제 값:  깨
# 출력 값:  나 , 실제 값:  나
# 출력 값:  수 , 실제 값:  수
# 출력 값:  살 , 실제 값:  살
# 출력 값:  석 , 실제 값:  석
# 출력 값:  명 , 실제 값:  명
# 출력 값:  품 , 실제 값:  품
# 출력 값:  목 , 실제 값:  목
# 출력 값:  버 , 실제 값:  버
# 출력 값:  꾸 , 실제 값:  꾸
# 출력 값:  나 , 실제 값:  나
# 출력 값:  치 , 실제 값:  치
# 출력 값:  지 , 실제 값:  지
# 출력 값:  바 , 실제 값:  바
# 출력 값:  오 , 실제 값:  오
# 출력 값:  필 , 실제 값:  필
# 출력 값:  들 , 실제 값:  들
# 출력 값:  쪽 , 실제 값:  쪽
# 출력 값:  경 , 실제 값:  경
# 출력 값:  심 , 실제 값:  심
# 출력 값:  드 , 실제 값:  드
# 출력 값:  답 , 실제 값:  답
# 출력 값:  관 , 실제 값:  관
# 출력 값:  내 , 실제 값:  내
# 출력 값:  토 , 실제 값:  토
# 출력 값:  위 , 실제 값:  위
# 출력 값:  현 , 실제 값:  현
# 출력 값:  늘 , 실제 값:  늘
# 출력 값:  잘 , 실제 값:  잘
# 출력 값:  근 , 실제 값:  근
# 출력 값:  구 , 실제 값:  구
# 출력 값:  사 , 실제 값:  사
# 출력 값:  데 , 실제 값:  데
# 출력 값:  합 , 실제 값:  합
# 출력 값:  상 , 실제 값:  상
# 출력 값:  진 , 실제 값:  진
# 출력 값:  내 , 실제 값:  내
# 출력 값:  업 , 실제 값:  업
# 출력 값:  중 , 실제 값:  중
# 출력 값:  창 , 실제 값:  창
# 출력 값:  조 , 실제 값:  조
# 출력 값:  터 , 실제 값:  터
# 출력 값:  회 , 실제 값:  회
# 출력 값:  처 , 실제 값:  처
# 출력 값:  름 , 실제 값:  름
# 출력 값:  하 , 실제 값:  하
# 출력 값:  단 , 실제 값:  단
# 출력 값:  로 , 실제 값:  로
# 출력 값:  은 , 실제 값:  은
# 출력 값:  화 , 실제 값:  화
# 출력 값:  복 , 실제 값:  복
# 출력 값:  색 , 실제 값:  색
# 출력 값:  니 , 실제 값:  니
# 출력 값:  청 , 실제 값:  청
# 출력 값:  특 , 실제 값:  특
# 출력 값:  민 , 실제 값:  민
# 출력 값:  소 , 실제 값:  소
# 출력 값:  환 , 실제 값:  환
# 출력 값:  없 , 실제 값:  없
# 출력 값:  환 , 실제 값:  환
# 출력 값:  전 , 실제 값:  전
# 출력 값:  원 , 실제 값:  원
# 출력 값:  결 , 실제 값:  결
# 출력 값:  감 , 실제 값:  감
# 출력 값:  해 , 실제 값:  해
# 출력 값:  버 , 실제 값:  버
# 출력 값:  보 , 실제 값:  보
# 출력 값:  직 , 실제 값:  직
# 출력 값:  력 , 실제 값:  력
# 출력 값:  구 , 실제 값:  구
# 출력 값:  침 , 실제 값:  침
# 출력 값:  합 , 실제 값:  합
# 출력 값:  본 , 실제 값:  본
# 출력 값:  분 , 실제 값:  분
# 출력 값:  없 , 실제 값:  없
# 출력 값:  구 , 실제 값:  구
# 출력 값:  음 , 실제 값:  음
# 출력 값:  시 , 실제 값:  시
# 출력 값:  질 , 실제 값:  질
# 출력 값:  되 , 실제 값:  되
# 출력 값:  유 , 실제 값:  유
# 출력 값:  태 , 실제 값:  태
# 출력 값:  체 , 실제 값:  체
# 출력 값:  트 , 실제 값:  트
# 출력 값:  국 , 실제 값:  국
# 출력 값:  너 , 실제 값:  너
# 출력 값:  십 , 실제 값:  십
# 출력 값:  육 , 실제 값:  육
# 출력 값:  결 , 실제 값:  결
# 출력 값:  민 , 실제 값:  민
# 출력 값:  문 , 실제 값:  문
# 출력 값:  라 , 실제 값:  라
# 출력 값:  습 , 실제 값:  습
# 출력 값:  주 , 실제 값:  주
# 출력 값:  적 , 실제 값:  적
# 출력 값:  변 , 실제 값:  변
# 출력 값:  담 , 실제 값:  담
# 출력 값:  질 , 실제 값:  질
# 출력 값:  침 , 실제 값:  침
# 출력 값:  보 , 실제 값:  보
# 출력 값:  심 , 실제 값:  심
# 출력 값:  형 , 실제 값:  형
# 출력 값:  마 , 실제 값:  마
# 출력 값:  삼 , 실제 값:  삼
# 출력 값:  눈 , 실제 값:  눈
# 출력 값:  타 , 실제 값:  타
# 출력 값:  히 , 실제 값:  히
# 출력 값:  역 , 실제 값:  역
# 출력 값:  업 , 실제 값:  업
# 출력 값:  석 , 실제 값:  석
# 출력 값:  루 , 실제 값:  루
# 출력 값:  새 , 실제 값:  새
# 출력 값:  대 , 실제 값:  대
# 출력 값:  스 , 실제 값:  스
# 출력 값:  인 , 실제 값:  인
# 출력 값:  은 , 실제 값:  은
# 출력 값:  면 , 실제 값:  면
# 출력 값:  십 , 실제 값:  십
# 출력 값:  영 , 실제 값:  영
# 출력 값:  실 , 실제 값:  실
# 출력 값:  망 , 실제 값:  망
# 출력 값:  해 , 실제 값:  해
# 출력 값:  남 , 실제 값:  남
# 출력 값:  올 , 실제 값:  올
# 출력 값:  의 , 실제 값:  의
# 출력 값:  무 , 실제 값:  무
# 출력 값:  노 , 실제 값:  노
# 출력 값:  열 , 실제 값:  열
# 출력 값:  필 , 실제 값:  필
# 출력 값:  기 , 실제 값:  기
# 출력 값:  려 , 실제 값:  려
# 출력 값:  전 , 실제 값:  전
# 출력 값:  코 , 실제 값:  코
# 출력 값:  최 , 실제 값:  최
# 출력 값:  양 , 실제 값:  양
# 출력 값:  식 , 실제 값:  식
# 출력 값:  마 , 실제 값:  마
# 출력 값:  면 , 실제 값:  면
# 출력 값:  소 , 실제 값:  소
# 출력 값:  녀 , 실제 값:  녀
# 출력 값:  담 , 실제 값:  담
# 출력 값:  눈 , 실제 값:  눈
# 출력 값:  고 , 실제 값:  고
# 출력 값:  만 , 실제 값:  만
# 출력 값:  비 , 실제 값:  비
# 출력 값:  어 , 실제 값:  어
# 출력 값:  초 , 실제 값:  초
# 출력 값:  노 , 실제 값:  노
# 출력 값:  집 , 실제 값:  집
# 출력 값:  발 , 실제 값:  발
# 출력 값:  로 , 실제 값:  로
# 출력 값:  데 , 실제 값:  데
# 출력 값:  근 , 실제 값:  근
# 출력 값:  직 , 실제 값:  직
# 출력 값:  천 , 실제 값:  천
# 출력 값:  출 , 실제 값:  출
# 출력 값:  경 , 실제 값:  경
# 출력 값:  품 , 실제 값:  품
# 출력 값:  합 , 실제 값:  합
# 출력 값:  종 , 실제 값:  종
# 출력 값:  계 , 실제 값:  계
# 출력 값:  거 , 실제 값:  거
# 출력 값:  쓰 , 실제 값:  쓰
# 출력 값:  작 , 실제 값:  작
# 출력 값:  작 , 실제 값:  작
# 출력 값:  강 , 실제 값:  강
# 출력 값:  리 , 실제 값:  리
# 출력 값:  점 , 실제 값:  점
# 출력 값:  머 , 실제 값:  머
# 출력 값:  눈 , 실제 값:  눈
# 출력 값:  주 , 실제 값:  주
# 출력 값:  조 , 실제 값:  조
# 출력 값:  살 , 실제 값:  살
# 출력 값:  비 , 실제 값:  비
# 출력 값:  세 , 실제 값:  세
# 출력 값:  차 , 실제 값:  차
# 출력 값:  매 , 실제 값:  매
# 출력 값:  안 , 실제 값:  안
# 출력 값:  혼 , 실제 값:  혼
# 출력 값:  능 , 실제 값:  능
# 출력 값:  요 , 실제 값:  요
# 출력 값:  복 , 실제 값:  복
# 출력 값:  술 , 실제 값:  술
# 출력 값:  상 , 실제 값:  상
# 출력 값:  잠 , 실제 값:  잠
# 출력 값:  울 , 실제 값:  울
# 출력 값:  출 , 실제 값:  출
# 출력 값:  속 , 실제 값:  속
# 출력 값:  미 , 실제 값:  미
# 출력 값:  주 , 실제 값:  주
# 출력 값:  아 , 실제 값:  아
# 출력 값:  창 , 실제 값:  창
# 출력 값:  안 , 실제 값:  안
# 출력 값:  갈 , 실제 값:  갈
# 출력 값:  의 , 실제 값:  의
# 출력 값:  석 , 실제 값:  석
# 출력 값:  변 , 실제 값:  변
# 출력 값:  드 , 실제 값:  드
# 출력 값:  험 , 실제 값:  험
# 출력 값:  추 , 실제 값:  추
# 출력 값:  되 , 실제 값:  되
# 출력 값:  두 , 실제 값:  두
# 출력 값:  부 , 실제 값:  부
# 출력 값:  순 , 실제 값:  순
# 출력 값:  종 , 실제 값:  종
# 출력 값:  갈 , 실제 값:  갈
# 출력 값:  국 , 실제 값:  국
# 출력 값:  모 , 실제 값:  모
# 출력 값:  삼 , 실제 값:  삼
# 출력 값:  별 , 실제 값:  별
# 출력 값:  발 , 실제 값:  발
# 출력 값:  머 , 실제 값:  머
# 출력 값:  노 , 실제 값:  노
# 출력 값:  나 , 실제 값:  나
# 출력 값:  트 , 실제 값:  트
# 출력 값:  재 , 실제 값:  재
# 출력 값:  방 , 실제 값:  방
# 출력 값:  매 , 실제 값:  매
# 출력 값:  히 , 실제 값:  히
# 출력 값:  법 , 실제 값:  법
# 출력 값:  본 , 실제 값:  본
# 출력 값:  색 , 실제 값:  색
# 출력 값:  손 , 실제 값:  손
# 출력 값:  판 , 실제 값:  판
# 출력 값:  반 , 실제 값:  반
# 출력 값:  매 , 실제 값:  매
# 출력 값:  부 , 실제 값:  부
# 출력 값:  거 , 실제 값:  거
# 출력 값:  내 , 실제 값:  내
# 출력 값:  화 , 실제 값:  화
# 출력 값:  일 , 실제 값:  일
# 출력 값:  잘 , 실제 값:  잘
# 출력 값:  루 , 실제 값:  루
# 출력 값:  일 , 실제 값:  일
# 출력 값:  달 , 실제 값:  달
# 출력 값:  토 , 실제 값:  토
# 출력 값:  머 , 실제 값:  머
# 출력 값:  참 , 실제 값:  참
# 출력 값:  물 , 실제 값:  물
# 출력 값:  전 , 실제 값:  전
# 출력 값:  필 , 실제 값:  필
# 출력 값:  기 , 실제 값:  기
# 출력 값:  국 , 실제 값:  국
# 출력 값:  포 , 실제 값:  포
# 출력 값:  바 , 실제 값:  바
# 출력 값:  말 , 실제 값:  말
# 출력 값:  호 , 실제 값:  호
# 출력 값:  청 , 실제 값:  청
# 출력 값:  십 , 실제 값:  십
# 출력 값:  녀 , 실제 값:  녀
# 출력 값:  격 , 실제 값:  격
# 출력 값:  들 , 실제 값:  들
# 출력 값:  순 , 실제 값:  순
# 출력 값:  용 , 실제 값:  용
# 출력 값:  대 , 실제 값:  대
# 출력 값:  타 , 실제 값:  타
# 출력 값:  질 , 실제 값:  질
# 출력 값:  외 , 실제 값:  외
# 출력 값:  증 , 실제 값:  증
# 출력 값:  군 , 실제 값:  군
# 출력 값:  날 , 실제 값:  날
# 출력 값:  비 , 실제 값:  비
# 출력 값:  눈 , 실제 값:  눈
# 출력 값:  수 , 실제 값:  수
# 출력 값:  별 , 실제 값:  별
# 출력 값:  버 , 실제 값:  버
# 출력 값:  색 , 실제 값:  색
# 출력 값:  입 , 실제 값:  입
# 출력 값:  늘 , 실제 값:  늘
# 출력 값:  잘 , 실제 값:  잘
# 출력 값:  난 , 실제 값:  난
# 출력 값:  쓰 , 실제 값:  쓰
# 출력 값:  위 , 실제 값:  위
# 출력 값:  저 , 실제 값:  저
# 출력 값:  청 , 실제 값:  청
# 출력 값:  유 , 실제 값:  유
# 출력 값:  역 , 실제 값:  역
# 출력 값:  벌 , 실제 값:  벌
# 출력 값:  고 , 실제 값:  고
# 출력 값:  난 , 실제 값:  난
# 출력 값:  명 , 실제 값:  명
# 출력 값:  잡 , 실제 값:  잡
# 출력 값:  장 , 실제 값:  장
# 출력 값:  초 , 실제 값:  초
# 출력 값:  수 , 실제 값:  수
# 출력 값:  저 , 실제 값:  저
# 출력 값:  독 , 실제 값:  독
# 출력 값:  다 , 실제 값:  다
# 출력 값:  차 , 실제 값:  차
# 출력 값:  생 , 실제 값:  생
# 출력 값:  열 , 실제 값:  열
# 출력 값:  참 , 실제 값:  참
# 출력 값:  요 , 실제 값:  요
# 출력 값:  려 , 실제 값:  려
# 출력 값:  난 , 실제 값:  난
# 출력 값:  삼 , 실제 값:  삼
# 출력 값:  면 , 실제 값:  면
# 출력 값:  생 , 실제 값:  생
# 출력 값:  성 , 실제 값:  성
# 출력 값:  담 , 실제 값:  담
# 출력 값:  체 , 실제 값:  체
# 출력 값:  설 , 실제 값:  설
# 출력 값:  산 , 실제 값:  산
# 출력 값:  울 , 실제 값:  울
# 출력 값:  임 , 실제 값:  임
# 출력 값:  번 , 실제 값:  번
# 출력 값:  증 , 실제 값:  증
# 출력 값:  목 , 실제 값:  목
# 출력 값:  불 , 실제 값:  불
# 출력 값:  스 , 실제 값:  스
# 출력 값:  사 , 실제 값:  사
# 출력 값:  꾸 , 실제 값:  꾸
# 출력 값:  목 , 실제 값:  목
# 출력 값:  야 , 실제 값:  야
# 출력 값:  살 , 실제 값:  살
# 출력 값:  벌 , 실제 값:  벌
# 출력 값:  후 , 실제 값:  후
# 출력 값:  절 , 실제 값:  절
# 출력 값:  독 , 실제 값:  독
# 출력 값:  성 , 실제 값:  성
# 출력 값:  력 , 실제 값:  력
# 출력 값:  름 , 실제 값:  름
# 출력 값:  자 , 실제 값:  자
# 출력 값:  회 , 실제 값:  회
# 출력 값:  러 , 실제 값:  러
# 출력 값:  력 , 실제 값:  력
# 출력 값:  음 , 실제 값:  음
# 출력 값:  극 , 실제 값:  극
# 출력 값:  드 , 실제 값:  드
# 출력 값:  예 , 실제 값:  예
# 출력 값:  영 , 실제 값:  영
# 출력 값:  길 , 실제 값:  길
# 출력 값:  절 , 실제 값:  절
# 출력 값:  래 , 실제 값:  래
# 출력 값:  코 , 실제 값:  코
# 출력 값:  들 , 실제 값:  들
# 출력 값:  별 , 실제 값:  별
# 출력 값:  울 , 실제 값:  울
# 출력 값:  창 , 실제 값:  창
# 출력 값:  확 , 실제 값:  확
# 출력 값:  해 , 실제 값:  해
# 출력 값:  자 , 실제 값:  자
# 출력 값:  교 , 실제 값:  교
# 출력 값:  물 , 실제 값:  물
# 출력 값:  초 , 실제 값:  초
# 출력 값:  소 , 실제 값:  소
# 출력 값:  분 , 실제 값:  분
# 출력 값:  우 , 실제 값:  우
# 출력 값:  식 , 실제 값:  식
# 출력 값:  송 , 실제 값:  송
# 출력 값:  개 , 실제 값:  개
# 출력 값:  양 , 실제 값:  양
# 출력 값:  어 , 실제 값:  어
# 출력 값:  배 , 실제 값:  배
# 출력 값:  지 , 실제 값:  지
# 출력 값:  건 , 실제 값:  건
# 출력 값:  심 , 실제 값:  심
# 출력 값:  복 , 실제 값:  복
# 출력 값:  단 , 실제 값:  단
# 출력 값:  건 , 실제 값:  건
# 출력 값:  절 , 실제 값:  절
# 출력 값:  바 , 실제 값:  바
# 출력 값:  술 , 실제 값:  술
# 출력 값:  료 , 실제 값:  료
# 출력 값:  처 , 실제 값:  처
# 출력 값:  처 , 실제 값:  처
# 출력 값:  갈 , 실제 값:  갈
# 출력 값:  면 , 실제 값:  면
# 출력 값:  이 , 실제 값:  이
# 출력 값:  증 , 실제 값:  증
# 출력 값:  필 , 실제 값:  필
# 출력 값:  후 , 실제 값:  후
# 출력 값:  디 , 실제 값:  디
# 출력 값:  안 , 실제 값:  안
# 출력 값:  름 , 실제 값:  름
# 출력 값:  워 , 실제 값:  워
# 출력 값:  포 , 실제 값:  포
# 출력 값:  최 , 실제 값:  최
# 출력 값:  한 , 실제 값:  한
# 출력 값:  추 , 실제 값:  추
# 출력 값:  도 , 실제 값:  도
# 출력 값:  외 , 실제 값:  외
# 출력 값:  배 , 실제 값:  배
# 출력 값:  요 , 실제 값:  요
# 출력 값:  세 , 실제 값:  세
# 출력 값:  호 , 실제 값:  호
# 출력 값:  표 , 실제 값:  표
# 출력 값:  호 , 실제 값:  호
# 출력 값:  과 , 실제 값:  과
# 출력 값:  의 , 실제 값:  의
# 출력 값:  독 , 실제 값:  독
# 출력 값:  님 , 실제 값:  님
# 출력 값:  서 , 실제 값:  서
# 출력 값:  움 , 실제 값:  움
# 출력 값:  서 , 실제 값:  서
# 출력 값:  일 , 실제 값:  일
# 출력 값:  사 , 실제 값:  사
# 출력 값:  키 , 실제 값:  키
# 출력 값:  울 , 실제 값:  울
# 출력 값:  장 , 실제 값:  장
# 출력 값:  침 , 실제 값:  침
# 출력 값:  학 , 실제 값:  학
# 출력 값:  참 , 실제 값:  참
# 출력 값:  행 , 실제 값:  행
# 출력 값:  난 , 실제 값:  난
# 출력 값:  영 , 실제 값:  영
# 출력 값:  지 , 실제 값:  지
# 출력 값:  입 , 실제 값:  입
# 출력 값:  체 , 실제 값:  체
# 출력 값:  시 , 실제 값:  시
# 출력 값:  토 , 실제 값:  토
# 출력 값:  과 , 실제 값:  과
# 출력 값:  최 , 실제 값:  최
# 출력 값:  만 , 실제 값:  만
# 출력 값:  표 , 실제 값:  표
# 출력 값:  피 , 실제 값:  피
# 출력 값:  하 , 실제 값:  하
# 출력 값:  씨 , 실제 값:  씨
# 출력 값:  강 , 실제 값:  강
# 출력 값:  기 , 실제 값:  기
# 출력 값:  쓰 , 실제 값:  쓰
# 출력 값:  향 , 실제 값:  향
# 출력 값:  음 , 실제 값:  음
# 출력 값:  편 , 실제 값:  편
# 출력 값:  예 , 실제 값:  예
# 출력 값:  벌 , 실제 값:  벌
# 출력 값:  정 , 실제 값:  정
# 출력 값:  예 , 실제 값:  예
# 출력 값:  미 , 실제 값:  미
# 출력 값:  통 , 실제 값:  통
# 출력 값:  약 , 실제 값:  약
# 출력 값:  도 , 실제 값:  도
# 출력 값:  발 , 실제 값:  발
# 출력 값:  편 , 실제 값:  편
# 출력 값:  계 , 실제 값:  계
# 출력 값:  신 , 실제 값:  신
# 출력 값:  프 , 실제 값:  프
# 출력 값:  방 , 실제 값:  방
# 출력 값:  디 , 실제 값:  디
# 출력 값:  책 , 실제 값:  책
# 출력 값:  향 , 실제 값:  향
# 출력 값:  편 , 실제 값:  편
# 출력 값:  활 , 실제 값:  활
# 출력 값:  신 , 실제 값:  신
# 출력 값:  개 , 실제 값:  개
# 출력 값:  상 , 실제 값:  상
# 출력 값:  업 , 실제 값:  업
# 출력 값:  술 , 실제 값:  술
# 출력 값:  철 , 실제 값:  철
# 출력 값:  각 , 실제 값:  각
# 출력 값:  올 , 실제 값:  올
# 출력 값:  일 , 실제 값:  일
# 출력 값:  과 , 실제 값:  과
# 출력 값:  오 , 실제 값:  오
# 출력 값:  망 , 실제 값:  망
# 출력 값:  도 , 실제 값:  도
# 출력 값:  길 , 실제 값:  길
# 출력 값:  모 , 실제 값:  모
# 출력 값:  이 , 실제 값:  이
# 출력 값:  책 , 실제 값:  책
# 출력 값:  교 , 실제 값:  교
# 출력 값:  간 , 실제 값:  간
# 출력 값:  제 , 실제 값:  제
# 출력 값:  태 , 실제 값:  태
# 출력 값:  아 , 실제 값:  아
# 출력 값:  되 , 실제 값:  되
# 출력 값:  대 , 실제 값:  대
# 출력 값:  움 , 실제 값:  움
# 출력 값:  무 , 실제 값:  무
# 출력 값:  교 , 실제 값:  교
# 출력 값:  집 , 실제 값:  집
# 출력 값:  동 , 실제 값:  동
# 출력 값:  격 , 실제 값:  격
# 출력 값:  험 , 실제 값:  험
# 출력 값:  출 , 실제 값:  출
# 출력 값:  설 , 실제 값:  설
# 출력 값:  하 , 실제 값:  하
# 출력 값:  연 , 실제 값:  연
# 출력 값:  미 , 실제 값:  미
# 출력 값:  무 , 실제 값:  무
# 출력 값:  말 , 실제 값:  말
# 출력 값:  십 , 실제 값:  십
# 출력 값:  급 , 실제 값:  급
# 출력 값:  학 , 실제 값:  학
# 출력 값:  극 , 실제 값:  극
# 출력 값:  추 , 실제 값:  추
# 출력 값:  코 , 실제 값:  코
# 출력 값:  은 , 실제 값:  은
# 출력 값:  습 , 실제 값:  습
# 출력 값:  노 , 실제 값:  노
# 출력 값:  길 , 실제 값:  길
# 출력 값:  답 , 실제 값:  답
# 출력 값:  법 , 실제 값:  법
# 출력 값:  터 , 실제 값:  터
# 출력 값:  루 , 실제 값:  루
# 출력 값:  답 , 실제 값:  답
# 출력 값:  치 , 실제 값:  치
# 출력 값:  행 , 실제 값:  행
# 출력 값:  단 , 실제 값:  단
# 출력 값:  성 , 실제 값:  성
# 출력 값:  남 , 실제 값:  남
# 출력 값:  양 , 실제 값:  양
# 출력 값:  새 , 실제 값:  새
# 출력 값:  화 , 실제 값:  화
# 출력 값:  인 , 실제 값:  인
# 출력 값:  주 , 실제 값:  주
# 출력 값:  비 , 실제 값:  비
# 출력 값:  아 , 실제 값:  아
# 출력 값:  잡 , 실제 값:  잡
# 출력 값:  경 , 실제 값:  경
# 출력 값:  키 , 실제 값:  키
# 출력 값:  달 , 실제 값:  달
# 출력 값:  책 , 실제 값:  책
# 출력 값:  조 , 실제 값:  조
# 출력 값:  실 , 실제 값:  실
# 출력 값:  내 , 실제 값:  내
# 출력 값:  송 , 실제 값:  송
# 출력 값:  먹 , 실제 값:  먹
# 출력 값:  서 , 실제 값:  서
# 출력 값:  건 , 실제 값:  건
# 출력 값:  프 , 실제 값:  프
# 출력 값:  식 , 실제 값:  식
# 출력 값:  장 , 실제 값:  장
# 출력 값:  한 , 실제 값:  한
# 출력 값:  차 , 실제 값:  차
# 출력 값:  당 , 실제 값:  당
# 출력 값:  육 , 실제 값:  육
# 출력 값:  개 , 실제 값:  개
# 출력 값:  쪽 , 실제 값:  쪽
# 출력 값:  로 , 실제 값:  로
# 출력 값:  니 , 실제 값:  니
# 출력 값:  진 , 실제 값:  진
# 출력 값:  강 , 실제 값:  강
# 출력 값:  진 , 실제 값:  진
# 출력 값:  속 , 실제 값:  속
# 출력 값:  변 , 실제 값:  변
# 출력 값:  날 , 실제 값:  날
# 출력 값:  포 , 실제 값:  포
# 출력 값:  법 , 실제 값:  법
# 출력 값:  회 , 실제 값:  회
# 출력 값:  침 , 실제 값:  침
# 출력 값:  우 , 실제 값:  우
# 출력 값:  운 , 실제 값:  운
# 출력 값:  약 , 실제 값:  약
# 출력 값:  야 , 실제 값:  야
# 출력 값:  독 , 실제 값:  독
# 출력 값:  사 , 실제 값:  사
# 출력 값:  삼 , 실제 값:  삼
# 출력 값:  별 , 실제 값:  별
# 출력 값:  철 , 실제 값:  철
# 출력 값:  럽 , 실제 값:  럽
# 출력 값:  라 , 실제 값:  라
# 출력 값:  결 , 실제 값:  결
# 출력 값:  선 , 실제 값:  선
# 출력 값:  락 , 실제 값:  락
# 출력 값:  번 , 실제 값:  번
# 출력 값:  혼 , 실제 값:  혼
# 출력 값:  험 , 실제 값:  험
# 출력 값:  형 , 실제 값:  형
# 출력 값:  피 , 실제 값:  피
# 출력 값:  실 , 실제 값:  실
# 출력 값:  습 , 실제 값:  습
# 출력 값:  간 , 실제 값:  간
# 출력 값:  다 , 실제 값:  다
# 출력 값:  장 , 실제 값:  장
# 출력 값:  험 , 실제 값:  험
# 출력 값:  스 , 실제 값:  스
# 출력 값:  깨 , 실제 값:  깨
# 출력 값:  길 , 실제 값:  길
# 출력 값:  천 , 실제 값:  천
# 출력 값:  쪽 , 실제 값:  쪽
# 출력 값:  날 , 실제 값:  날
# 출력 값:  목 , 실제 값:  목
# 출력 값:  현 , 실제 값:  현
# 출력 값:  르 , 실제 값:  르
# 출력 값:  락 , 실제 값:  락
# 출력 값:  실 , 실제 값:  실
# 출력 값:  하 , 실제 값:  하
# 출력 값:  선 , 실제 값:  선
# 출력 값:  특 , 실제 값:  특
# 출력 값:  데 , 실제 값:  데
# 출력 값:  본 , 실제 값:  본
# 출력 값:  모 , 실제 값:  모
# 출력 값:  외 , 실제 값:  외
# 출력 값:  재 , 실제 값:  재
# 출력 값:  경 , 실제 값:  경
# 출력 값:  극 , 실제 값:  극
# 출력 값:  료 , 실제 값:  료
# 출력 값:  머 , 실제 값:  머
# 출력 값:  앞 , 실제 값:  앞
# 출력 값:  작 , 실제 값:  작
# 출력 값:  깨 , 실제 값:  깨
# 출력 값:  육 , 실제 값:  육
# 출력 값:  원 , 실제 값:  원
# 출력 값:  깨 , 실제 값:  깨
# 출력 값:  관 , 실제 값:  관
# 출력 값:  단 , 실제 값:  단
# 출력 값:  료 , 실제 값:  료
# 출력 값:  종 , 실제 값:  종
# 출력 값:  밤 , 실제 값:  밤
# 출력 값:  터 , 실제 값:  터
# 출력 값:  계 , 실제 값:  계
# 출력 값:  확 , 실제 값:  확
# 출력 값:  없 , 실제 값:  없
# 출력 값:  용 , 실제 값:  용
# 출력 값:  르 , 실제 값:  르
# 출력 값:  근 , 실제 값:  근
# 출력 값:  혼 , 실제 값:  혼
# 출력 값:  여 , 실제 값:  여
# 출력 값:  접 , 실제 값:  접
# 출력 값:  역 , 실제 값:  역
# 출력 값:  니 , 실제 값:  니
# 출력 값:  세 , 실제 값:  세
# 출력 값:  형 , 실제 값:  형
# 출력 값:  호 , 실제 값:  호
# 출력 값:  정 , 실제 값:  정
# 출력 값:  천 , 실제 값:  천
# 출력 값:  동 , 실제 값:  동
# 출력 값:  절 , 실제 값:  절
# 출력 값:  중 , 실제 값:  중
# 출력 값:  디 , 실제 값:  디
# 출력 값:  어 , 실제 값:  어
# 출력 값:  라 , 실제 값:  라
# 출력 값:  락 , 실제 값:  락
# 출력 값:  상 , 실제 값:  상
# 출력 값:  참 , 실제 값:  참
# 출력 값:  씨 , 실제 값:  씨
# 출력 값:  심 , 실제 값:  심
# 출력 값:  현 , 실제 값:  현
# 출력 값:  움 , 실제 값:  움
# 출력 값:  속 , 실제 값:  속
# 출력 값:  용 , 실제 값:  용
# 출력 값:  금 , 실제 값:  금
# 출력 값:  그 , 실제 값:  그
# 출력 값:  건 , 실제 값:  건
# 출력 값:  연 , 실제 값:  연
# 출력 값:  의 , 실제 값:  의
# 출력 값:  래 , 실제 값:  래
# 출력 값:  밤 , 실제 값:  밤
# 출력 값:  월 , 실제 값:  월
# 출력 값:  없 , 실제 값:  없
# 출력 값:  님 , 실제 값:  님
# 출력 값:  야 , 실제 값:  야
# 출력 값:  잠 , 실제 값:  잠
# 출력 값:  열 , 실제 값:  열
# 출력 값:  개 , 실제 값:  개
# 출력 값:  능 , 실제 값:  능
# 출력 값:  워 , 실제 값:  워
# 출력 값:  시 , 실제 값:  시
# 출력 값:  후 , 실제 값:  후
# 출력 값:  약 , 실제 값:  약
# 출력 값:  문 , 실제 값:  문
# 출력 값:  배 , 실제 값:  배
# 출력 값:  형 , 실제 값:  형
# 출력 값:  데 , 실제 값:  데
# 출력 값:  당 , 실제 값:  당
# 출력 값:  관 , 실제 값:  관
# 출력 값:  앞 , 실제 값:  앞
# 출력 값:  천 , 실제 값:  천
# 출력 값:  특 , 실제 값:  특
# 출력 값:  포 , 실제 값:  포
# 출력 값:  공 , 실제 값:  공
# 출력 값:  감 , 실제 값:  감
# 출력 값:  리 , 실제 값:  리
# 출력 값:  유 , 실제 값:  유
# 출력 값:  잘 , 실제 값:  잘
# 출력 값:  당 , 실제 값:  당
# 출력 값:  산 , 실제 값:  산
# 출력 값:  러 , 실제 값:  러
# 출력 값:  되 , 실제 값:  되
# 출력 값:  직 , 실제 값:  직
# 출력 값:  반 , 실제 값:  반
# 출력 값:  잠 , 실제 값:  잠
# 출력 값:  표 , 실제 값:  표
# 출력 값:  영 , 실제 값:  영
# 출력 값:  새 , 실제 값:  새
# 출력 값:  금 , 실제 값:  금
# 출력 값:  임 , 실제 값:  임
# 출력 값:  급 , 실제 값:  급
# 출력 값:  공 , 실제 값:  공
# 출력 값:  국 , 실제 값:  국
# 출력 값:  표 , 실제 값:  표
# 출력 값:  당 , 실제 값:  당
# 출력 값:  늘 , 실제 값:  늘
# 출력 값:  최 , 실제 값:  최
# 출력 값:  분 , 실제 값:  분
# 출력 값:  두 , 실제 값:  두
# 출력 값:  어 , 실제 값:  어
# 출력 값:  불 , 실제 값:  불
# 출력 값:  우 , 실제 값:  우
# 출력 값:  프 , 실제 값:  프
# 출력 값:  차 , 실제 값:  차
# 출력 값:  선 , 실제 값:  선
# 출력 값:  초 , 실제 값:  초
# 출력 값:  처 , 실제 값:  처
# 출력 값:  바 , 실제 값:  바
# 출력 값:  그 , 실제 값:  그
# 출력 값:  각 , 실제 값:  각
# 출력 값:  다 , 실제 값:  다
# 출력 값:  앞 , 실제 값:  앞
# 출력 값:  워 , 실제 값:  워
# 출력 값:  조 , 실제 값:  조
# 출력 값:  이 , 실제 값:  이
# 출력 값:  남 , 실제 값:  남
# 출력 값:  체 , 실제 값:  체
# 출력 값:  명 , 실제 값:  명
# 출력 값:  손 , 실제 값:  손
# 출력 값:  한 , 실제 값:  한
# 출력 값:  타 , 실제 값:  타
# 출력 값:  환 , 실제 값:  환
# 출력 값:  그 , 실제 값:  그
# 출력 값:  적 , 실제 값:  적
# 출력 값:  도 , 실제 값:  도
# 출력 값:  편 , 실제 값:  편
# 출력 값:  날 , 실제 값:  날
# 출력 값:  기 , 실제 값:  기
# 출력 값:  번 , 실제 값:  번
# 출력 값:  거 , 실제 값:  거
# 출력 값:  계 , 실제 값:  계
# 출력 값:  럽 , 실제 값:  럽
# 출력 값:  결 , 실제 값:  결
# 출력 값:  감 , 실제 값:  감
# 출력 값:  요 , 실제 값:  요
# 출력 값:  올 , 실제 값:  올
# 출력 값:  행 , 실제 값:  행
# 출력 값:  가 , 실제 값:  가
# 출력 값:  모 , 실제 값:  모
# 출력 값:  판 , 실제 값:  판
# 출력 값:  저 , 실제 값:  저
# 출력 값:  급 , 실제 값:  급
# 출력 값:  임 , 실제 값:  임
# 출력 값:  키 , 실제 값:  키
# 출력 값:  성 , 실제 값:  성
# 출력 값:  방 , 실제 값:  방
# 출력 값:  님 , 실제 값:  님
# 출력 값:  연 , 실제 값:  연
# 출력 값:  대 , 실제 값:  대
# 출력 값:  너 , 실제 값:  너
# 출력 값:  민 , 실제 값:  민
# 출력 값:  회 , 실제 값:  회
# 출력 값:  명 , 실제 값:  명
# 출력 값:  담 , 실제 값:  담
# 출력 값:  원 , 실제 값:  원
# 출력 값:  태 , 실제 값:  태
# 출력 값:  역 , 실제 값:  역
# 출력 값:  강 , 실제 값:  강
# 출력 값:  활 , 실제 값:  활
# 출력 값:  열 , 실제 값:  열
# 출력 값:  수 , 실제 값:  수
# 출력 값:  교 , 실제 값:  교
# 출력 값:  급 , 실제 값:  급
# 출력 값:  늘 , 실제 값:  늘
# 출력 값:  매 , 실제 값:  매
# 출력 값:  밤 , 실제 값:  밤
# 출력 값:  판 , 실제 값:  판
# 출력 값:  혼 , 실제 값:  혼
# 출력 값:  여 , 실제 값:  여
# 출력 값:  파 , 실제 값:  파
# 출력 값:  태 , 실제 값:  태
# 출력 값:  씨 , 실제 값:  씨
# 출력 값:  출 , 실제 값:  출
# 출력 값:  평 , 실제 값:  평
# 출력 값:  동 , 실제 값:  동
# 출력 값:  두 , 실제 값:  두
# 출력 값:  철 , 실제 값:  철
# 출력 값:  송 , 실제 값:  송
# 출력 값:  살 , 실제 값:  살
# 출력 값:  새 , 실제 값:  새
# 출력 값:  설 , 실제 값:  설
# 출력 값:  위 , 실제 값:  위
# 출력 값:  남 , 실제 값:  남
# 출력 값:  현 , 실제 값:  현
# 출력 값:  월 , 실제 값:  월
# 출력 값:  가 , 실제 값:  가
# 출력 값:  관 , 실제 값:  관
# 출력 값:  달 , 실제 값:  달
# 출력 값:  신 , 실제 값:  신
# 출력 값:  답 , 실제 값:  답
# 출력 값:  벌 , 실제 값:  벌
# 출력 값:  트 , 실제 값:  트
# 출력 값:  증 , 실제 값:  증
# 출력 값:  인 , 실제 값:  인
# 출력 값:  리 , 실제 값:  리
# 출력 값:  약 , 실제 값:  약
# 출력 값:  용 , 실제 값:  용
# 출력 값:  제 , 실제 값:  제
# 출력 값:  철 , 실제 값:  철
# 출력 값:  접 , 실제 값:  접
# 출력 값:  행 , 실제 값:  행
# 출력 값:  능 , 실제 값:  능
# 출력 값:  들 , 실제 값:  들
# 출력 값:  먹 , 실제 값:  먹
# 출력 값:  직 , 실제 값:  직
# 출력 값:  여 , 실제 값:  여
# 출력 값:  청 , 실제 값:  청
# 출력 값:  종 , 실제 값:  종
# 출력 값:  입 , 실제 값:  입
# 출력 값:  래 , 실제 값:  래
# 출력 값:  버 , 실제 값:  버
# 출력 값:  래 , 실제 값:  래
# 출력 값:  이 , 실제 값:  이
# 출력 값:  파 , 실제 값:  파
# 출력 값:  운 , 실제 값:  운
# 출력 값:  고 , 실제 값:  고
# 출력 값:  아 , 실제 값:  아
# 출력 값:  피 , 실제 값:  피
# 출력 값:  만 , 실제 값:  만
# 출력 값:  너 , 실제 값:  너
# 출력 값:  원 , 실제 값:  원
# 출력 값:  위 , 실제 값:  위
# 출력 값:  로 , 실제 값:  로
# 출력 값:  활 , 실제 값:  활
# 출력 값:  적 , 실제 값:  적
# 출력 값:  입 , 실제 값:  입
# 출력 값:  문 , 실제 값:  문
# 출력 값:  평 , 실제 값:  평
# 출력 값:  후 , 실제 값:  후
# 출력 값:  본 , 실제 값:  본
# 출력 값:  유 , 실제 값:  유
# 출력 값:  색 , 실제 값:  색
# 출력 값:  자 , 실제 값:  자
# 출력 값:  잡 , 실제 값:  잡
# 출력 값:  러 , 실제 값:  러
# 출력 값:  말 , 실제 값:  말
# 출력 값:  님 , 실제 값:  님
# 출력 값:  격 , 실제 값:  격
# 출력 값:  진 , 실제 값:  진
# 출력 값:  분 , 실제 값:  분
# 출력 값:  달 , 실제 값:  달
# 출력 값:  금 , 실제 값:  금
# 출력 값:  운 , 실제 값:  운

# %%
sum=0
for i in range(len(scoreboard)):
    sum+=int(scoreboard[i])
performance=sum/len(scoreboard)*100
print("performance: ",performance,"%")
# Out:
# performance:  100.0 %
